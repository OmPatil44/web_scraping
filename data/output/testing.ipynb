# %%
import pandas as pd

df = pd.read_csv('extracted_data.csv')

df
# Out:
#                                          product_name current_price  \
# 0   Nayajaisa ProBook 430 G5 13.3inch FHD Laptop I...       ₹20,699
# 1   Ultimus Elite Intel Core i5 10th Gen 1035G4 - ...       ₹27,990
# 2   WarnerCann Hi5 pro Intel Core i5 12th Gen - (8...       ₹29,800
# 3   Avita E Series Intel Core i5 12th Gen 1235U - ...       ₹30,999
# 4   WINGS Nuvobook V1 Aluminium Alloy Metal Body I...       ₹34,990
# 5   Thomson NEO Core Series Intel Core i5 12th Gen...       ₹35,990
# 6   Acer One Intel Core i3 11th Gen 1115G4 - (8 GB...       ₹24,999
# 7   Avita Liber E Intel Core i3 12th Gen 1215U - (...       ₹24,999
# 8   Avita E Series Intel Core i3 12th Gen 1215U - ...       ₹24,999
# 9   ASUS VivoBook 15 Intel Core i3 10th Gen 1005G1...       ₹27,990
# 10  ASUS Vivobook 15 Intel Core i3 11th Gen 1115G4...       ₹28,990
# 11  Thomson NEO Core Series Intel Core i3 12th Gen...       ₹24,999
#
#    original_price discount_percentage  rating review_count
# ...
